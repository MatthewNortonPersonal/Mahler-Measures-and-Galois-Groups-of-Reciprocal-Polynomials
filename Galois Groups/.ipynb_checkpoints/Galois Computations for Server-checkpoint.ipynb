# %% [markdown]
# ## Initial Setup
#
# Below are some imports and function definitions required for doing the computations.

# %%
import pandas as pd
import time

# %%
A.<x> = PolynomialRing(CC)
R.<x> = PolynomialRing(QQ)

# %%
def boxedPolys(d, b, bound = -1):
    n = d / 2
    bounds = [b * 2 + 1 for i in range(n)]
    # print(bounds)
    
    possibleCoef = xmrange(bounds)
    polys = []
    counter = 0
    for coefs in possibleCoef:
        if(bound != -1 and counter == bound):
            break;
        counter += 1

        coefs = [1] + [coef - b for coef in coefs]
        coefs.extend(coefs[:-1][::-1])
        poly = R(coefs)
        
        if not poly.is_irreducible():
            # print(coefs)
            continue
            
        # The section below is for if you want to filter out cyclotomic
        # polynomials and polynomials of high Mahler measure. You need to add
        # an extra parameter, M, to the function then
#         mahler = mahlerMeasure(poly)
        
#         # print(coefs)
        
#         if mahler > M or mahler == 1:
#             # print(mahler)
#             # print("high")
#             continue
        
        polys.append(poly)
    return polys
        
def mahlerMeasure(poly):
    tempPoly = A(poly)
    rootList = list(tempPoly.roots())
    measure = 1
    
    for s in rootList:
        s_2 = sqrt(norm(s[0]))
        measure = measure * max(1, s_2)

    return measure

# %%
# filters out the reducibles from the list of polynomial objects
def filterOutReducibles(polys):
    newPolys = []
    for poly in polys:
        if poly.is_irreducible():
            newPolys.append(poly)
    return newPolys


# computes the galois group for the given polynomial.
def getGalois(poly):
    # make sure the polynomial is not reducible before
    # computing its Galois group
    # assert poly.is_irreducible()
    K.<a> = NumberField(poly)
    G = K.galois_group()
    return G
    # return G.transitive_label()

def convertToPoly(coefs):
    # Define a polynomial ring for our polynomials and convert coefs to poly using this ring
    R = PolynomialRing(QQ, 'x')
    return R(coefs)


# function to get the roots and Mahler measure

#Returns roots w norm greater than 1
def bigRoots(poly): 
    S.<x> = PolynomialRing(CC)
    tempPoly = S(poly)
    rootList = tempPoly.roots()
    bigRootList = []
    for r in rootList:
        if sqrt(norm(r[0])) > 1:
            bigRootList.append(r)

    return len(bigRootList)

def realRoots(poly): 
    L.<b> = PolynomialRing(RR)
    tempPoly = L(poly)
    rootList = list(tempPoly.roots())
    realRootList = []
    for r in rootList:
        if r[0] == conjugate(r[0]):
            realRootList.append(r)

    return len(realRootList)

def mahlerMeasure(poly):
    S.<x> = PolynomialRing(CC)
    tempPoly = S(poly)
    rootList = list(tempPoly.roots())
    measure = 1
    
    # print(rootList)
    
    # question: are we dealing with multiplicity correctly?
    for s in rootList:
        s_2 = sqrt(norm(s[0]))
        measure = measure * max(1, s_2)

    return measure

#Returns trace polynomial 
def tracePoly(poly):
    K.<a> = NumberField(poly)
    return (a + 1/a).minpoly()

# one goal: plot the number of polynomials with Mahler Measure under a certain bound
# as you increase the degree

# things we want to collect:
# ((f) poly, roots of f outside unit circle, # of real roots, (g) trace poly, G_f, G_g, Mahler, disc)
# collect data into a csv (so we can plot it)

def getStats(poly):
    # poly, degree, Mahler measure, roots outside unit circle, # real roots, trace poly, galois of poly, galois of trace, discriminant, 
    trace = tracePoly(poly)
    polyGalois = getGalois(poly)
    polyGaloisLabel = polyGalois.transitive_label()
#     print(type(polyGalois))
#     print(polyGalois.transitive_number())
    traceGalois = getGalois(trace)
    traceGaloisLabel = traceGalois.transitive_label()
    return [poly 
            , poly.degree()
            , mahlerMeasure(poly) 
            , bigRoots(poly) # roots outside unit circle
            , realRoots(poly) 
            , trace
            , polyGaloisLabel
            , traceGaloisLabel
            , disc(poly) # discriminant
            , polyGalois.order()
            , traceGalois.order()
            , polyGalois.order() / traceGalois.order()
          ]

# %%
headers = ["polynomial", "degree", "Mahler measure", "roots outside unit circle", 
           "number of real roots", "trace poly", "Galois of poly", "Galois of trace", 
           "discriminant", "galois order", "trace galois order", "galois ratio"]

# %% [markdown]
# ## Data Collection
# Set your value of d (degree) and b (bound for coefficients) here. It will also track and print out the time taken to complete all computations.
#
# Feel free to combine the two functions into the same cell if you want the computations to be done all at once.

# %%
d = 8
b = 2

#total number of polynomials is (2b+1)^(d/2). I want to spend an hour on each degree.

# %%
# start_time = time.time()

# polys = boxedPolys(12, 1)
# print(polys)
# polyData = [getStats(poly) for poly in polys]
# df = pd.DataFrame(polyData)
# df.columns = headers

# end_time = time.time()
# sec = end_time - start_time
# print(sec)
# #total number of polynomials is (2b+1)^(d/2). I want to spend an hour on each degree. 
# #Here, we processed 3^(d/2) polynomials So, I'm happy to process 3^(d/2)/sec*3600 polynomials.

# %%
from multiprocessing import Pool
def run(d, num_cores = 24):
    start_time = time.time()

    polys = boxedPolys(d, 1)
    polyData = [getStats(poly) for poly in polys]
    df = pd.DataFrame(polyData)
    df.columns = headers

    end_time = time.time()
    sec = end_time - start_time
    
#     print(sec)
    #total number of polynomials is (2b+1)^(d/2). I want to spend an hour on each degree. 
    #Here, we processed 3^(d/2) polynomials So, I'm happy to process 3^(d/2)/sec*3600 polynomials.
    #So, I want to find b so that (2b+1)^(d/2) = 3^(d/2)/sec*3600. That is, 
    #(2b+1)=3*(3600/sec)^(2/d)
    #So, b = (3*(3600/sec)^(2/d)-1)/2
    b = floor((3*(3600*num_cores/sec)^(2/d)-1)/2)
    print(b)
    polys = boxedPolys(d, b)
    with Pool() as pool: 
        polyData = pool.map(getStats, polys)
    polyData = [getStats(poly) for poly in polys]
    df = pd.DataFrame(polyData)
    df.columns = headers
    df.to_csv(f'degree {d} up to {b}')

# %%
run(8)
run(10)
# Out:
# 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6631/634500874.py in <module>
# ----> 1 run(Integer(8),num_cores = Integer(1))
#
# /tmp/ipykernel_6631/419677807.py in run(d, num_cores)
#      19     b = floor((Integer(3)*(Integer(3600)*num_cores/sec)**(Integer(2)/d)-Integer(1))/Integer(2))
#      20     print(b)
# ---> 21     polys = boxedPolys(d, b)
#      22     with Pool() as pool:
#      23         polyData = pool.map(getStats, polys)
#
# /tmp/ipykernel_6631/335700649.py in boxedPolys(d, b, bound)
#      16         poly = R(coefs)
#      17
# ---> 18         if not poly.is_irreducible():
#      19             # print(coefs)
#      20             continue
#
# /usr/lib/python3/dist-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCallerNoArgs.__call__ (build/cythonized/sage/misc/cachefunc.c:12999)()
#    2308         if self.cache is None:
#    2309             f = self.f
# -> 2310             self.cache = f(self._instance)
#    2311         return self.cache
#    2312
#
# /usr/lib/python3/dist-packages/sage/rings/polynomial/polynomial_rational_flint.pyx in sage.rings.polynomial.polynomial_rational_flint.Polynomial_rational_flint.is_irreducible (build/cythonized/sage/rings/polynomial/polynomial_rational_flint.cpp:15546)()
#    1643             fmpz_poly_primitive_part(primitive.__poly, primitive.__poly)
#    1644             sig_off()
# -> 1645             return primitive.is_irreducible()
#    1646
#    1647     #######################################################
#
# /usr/lib/python3/dist-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCallerNoArgs.__call__ (build/cythonized/sage/misc/cachefunc.c:12999)()
#    2308         if self.cache is None:
#    2309             f = self.f
# -> 2310             self.cache = f(self._instance)
#    2311         return self.cache
#    2312
#
# /usr/lib/python3/dist-packages/sage/rings/polynomial/polynomial_element.pyx in sage.rings.polynomial.polynomial_element.Polynomial.is_irreducible (build/cythonized/sage/rings/polynomial/polynomial_element.c:74441)()
#    9045             return B._is_irreducible_univariate_polynomial(self)
#    9046
# -> 9047         F = self.factor()
#    9048         if len(F) > 1 or F[0][1] > 1:
#    9049             return False
#
# /usr/lib/python3/dist-packages/sage/rings/polynomial/polynomial_integer_dense_flint.pyx in sage.rings.polynomial.polynomial_integer_dense_flint.Polynomial_integer_dense_flint.factor (build/cythonized/sage/rings/polynomial/polynomial_integer_dense_flint.cpp:16740)()
#    1646         g = self//c
#    1647         if deg < 30 or deg > 300:
# -> 1648             return c.factor()*g._factor_ntl()
#    1649         else:
#    1650             return c.factor()*g._factor_pari()
#
# /usr/lib/python3/dist-packages/sage/rings/polynomial/polynomial_integer_dense_flint.pyx in sage.rings.polynomial.polynomial_integer_dense_flint.Polynomial_integer_dense_flint._factor_ntl (build/cythonized/sage/rings/polynomial/polynomial_integer_dense_flint.cpp:16577)()
#    1612             fmpz_poly_set_ZZX(fac_py.__poly, factors.RawGet(i).a)
#    1613             results.append( (fac_py,factors.RawGet(i).b) )
# -> 1614         return Factorization(results, unit = unit)
#    1615
#    1616     def factor(self):
#
# /usr/lib/python3/dist-packages/sage/structure/factorization.py in __init__(self, x, unit, cr, sort, simplify)
#     213         TypeError: no conversion of this rational to integer
#     214     """
# --> 215     def __init__(self, x, unit=None, cr=False, sort=True, simplify=True):
#     216         """
#     217         Create a :class:`Factorization` object.
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
